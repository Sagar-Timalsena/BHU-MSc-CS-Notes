# %%
import matplotlib.pyplot as plt
arr = 10,12,13,12,14,15,15,15,13,12,11
plt.plot(arr)

# %%
plt.hist([arr,arr], bins=10, edgecolor = "black",color=["aqua","orange"], rwidth=0.9,label=["array1","array2"])
plt.legend(loc="upper left")
plt.xlabel("array")
plt.ylabel("frequency")
plt.title("testing")
# Out:
# Text(0.5, 1.0, 'testing')

# %%
# x = [10,20,30,40,50,60]
# y = [10,20,30,40,50,60]
import numpy as np
plt.style.use('fivethirtyeight')
x = np.linspace(1,10,20)
y = np.log10(x)
x1 = np.linspace(1,10,20)
y1 = np.exp(x1)
plt.plot(x1,y1,linestyle = '--',marker = 'o',label="exp")
# print(type(x))
# print(x)
# for i in range(50):

plt.plot(x,y,label = "log")
plt.legend()
# plt.tight_layout()
plt.grid(True)
plt.show()
